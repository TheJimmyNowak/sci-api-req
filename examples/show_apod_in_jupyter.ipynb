# %%
import datetime
import config
from providers.NASA.apod_provider import APODProvider
from IPython.display import Image

#Set key for NASA API
config.set_api_keys(('NASA', 'CeJOODBdDRDhAbcsB4H89tSIJFkUD0hCkQu760nf'))

#Initialize provider
provider = APODProvider()
#Get image from 19.08.2019
url = provider.get_apod(date=datetime.date(2019,8, 19))['url']

#Show image. Sometimes NASA put videos!!!
Image(url)
